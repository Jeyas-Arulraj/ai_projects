# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True, dtype=int)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset.columns
dataset=dataset.drop("User ID",axis=1)

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
indep=dataset[["Age","EstimatedSalary","Gender_Male"]]
dep=dataset["Purchased"]

# %%
indep.shape
# Out:
# (400, 3)

# %%
dep
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier=classifier.fit(X_train, y_train)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, y_pred)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.96      0.85        85
#            1       0.88      0.47      0.61        49
#
#     accuracy                           0.78       134
#    macro avg       0.82      0.72      0.73       134
# weighted avg       0.81      0.78      0.76       134

# %%
print(cm)
# Out:
# [[82  3]
#  [26 23]]

# %%
classifier.predict([[40,300,1,]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
#SVM classification:
#==================
# 1. waht is the recall of (0)? ans => 0.96
#(or) what is the correct performance of non purches? ans => 0.96

# 2. waht is the recall of (1)? ans => 0.84
#(or) what is the correct performance of  purches? ans => 0.47

#3.what is the over all performance of accuracy?  ans => 0.78

#4.what is the performance of  precision (0) or non purches?  ans => 0.76
#5.what is the performance of  precision (1) or  purches?  ans => 0.88

#6.what is the performance of f1-score of (0)?  ans => 0.85
#7.what is the performance of f1-score of (1)?  ans => 0.61

#3.what is the macro avg of precision?  ans => 0.82
#3.what is the macro avg of recall?  ans => 0.72
#3.what is the macro avg of  f1-score?  ans => 0.73
#3.what is the weighted avg of precision?  ans => 0.81
#3.what is the weighted avg of recall?  ans => 0.78
#3.what is the weighted avg of f1-score?  ans => 0.76

#3.what is the support of 0?  ans => 85
#3.what is the support of 1?  ans => 49
#3.what is the support of accuracy?  ans => 134
#3.what is the support of  macro avg?  ans => 134
#3.what is the support of weighted avg?  ans => 134
