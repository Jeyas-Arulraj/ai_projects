# %%
import pandas as pd
import numpy as np
dataset=pd.read_csv("PrePlacement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       0.0
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       0.0
#
# [215 rows x 15 columns]

# %% [markdown]
# Question-1: Replace the NaN values with correct value. And justify why you have chosen the same.¶

# %%
dataset.isnull().sum() #check for null values
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset["salary"].fillna(0,inplace=True)
#replace NaN values in salary column with 0 , another way : dataset["salary"]=dataset["salary"].fillna(0)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19444\3586656384.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["salary"].fillna(0,inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       0.0
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       0.0
#
# [215 rows x 15 columns]

# %%
dataset.isnull().sum() #verify null values again
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# Explanation:
#     The salary column contains 67 missing values because those students were not placed.
#
#     Since non-placed students do not receive any salary,
#
#     replacing NaN with 0 is meaningful and preserves all records in the dataset.

# %% [markdown]
# Question-2)How many of them are not placed?

# %%
not_placed=dataset[dataset["status"]=="Not Placed"] #we are loading not-placed students data into one variable
print('No.of students not placed:',len(not_placed)) #we can see the count using len function
# Out:
# No.of students not placed: 67

# %% [markdown]
# Explanation:
# The status column indicates whether a student is placed or not placed.
# By filtering the dataset for "Not Placed", we found that 67 students were not placed.

# %% [markdown]
# Question-3)Find the reason for non placement from the dataset?

# %%
not_placed.describe()
# Out:
#             sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# count   67.000000  67.000000  67.000000  67.000000  67.000000  67.000000
# mean   110.477612  57.544030  58.598358  61.134179  69.587910  61.612836
# std     65.859667   8.394246   9.537395   6.365825  11.930687   5.705689
# min      4.000000  40.890000  42.750000  50.000000  50.000000  51.210000
# 25%     48.500000  52.000000  51.000000  57.000000  60.000000  58.480000
# 50%    107.000000  56.280000  60.330000  61.000000  67.000000  60.690000
# 75%    170.500000  63.000000  64.000000  65.000000  76.500000  65.405000
# max    215.000000  77.800000  82.000000  79.000000  97.000000  75.710000
#
#        salary
# count    67.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %% [markdown]
# Explanation:
# The dataset does not contain a specific column mentioning the reason for non-placement.
# However, after analysing the non-placed students' record, we can see the factor such as,
# - lower academic percentages,
# - lower entrance test scores, degree mark also low.

# %% [markdown]
# Question-4)What kind of relation between salary and mba_p

# %%
dataset.corr(numeric_only=True) #this is overall correlation between all the columns
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.090500 -0.091039  0.063636  0.022327  0.001217
# ssc_p    -0.078155  1.000000  0.513478  0.538686  0.261993  0.388478  0.558475
# hsc_p    -0.090500  0.513478  1.000000  0.434606  0.240775  0.348452  0.459424
# degree_p -0.091039  0.538686  0.434606  1.000000  0.227147  0.402376  0.423762
# etest_p   0.063636  0.261993  0.240775  0.227147  1.000000  0.218055  0.186775
# mba_p     0.022327  0.388478  0.348452  0.402376  0.218055  1.000000  0.141417
# salary    0.001217  0.558475  0.459424  0.423762  0.186775  0.141417  1.000000

# %%
correlation=dataset["salary"].corr(dataset["mba_p"]) #specifically see the correlation between salary and mba_p

# %%
print("correlation between salary and mba_p :",correlation)
# Out:
# correlation between salary and mba_p : 0.14141713944325943

# %% [markdown]
# Explanation:
# The correlation value is 0.1398, which indicates a very weak positive relationship between MBA nad salary.
#
#
#
#
#
#
#
# Question-5)Which specialization is getting minimum salary?

# %%
specialization_salary=dataset.groupby("specialisation")["salary"].mean()

# %%
specialization_salary
# Out:
# specialisation
# Mkt&Fin    234643.750000
# Mkt&HR     150842.105263
# Name: salary, dtype: float64

# %%
minimum_salary_specialization=specialization_salary.idxmin()
print("Specialization with minimum salary:",minimum_salary_specialization)
# Out:
# Specialization with minimum salary: Mkt&HR

# %% [markdown]
# Explanation:
# The average salary of students from Mkt&HR specialization is lower than Mkt&Fin
#
# Question-6)How many of them getting above 500000 salary?¶

# %%
above_500000=dataset[dataset["salary"]>500000] #by filtering above 5,00,000 salary's student's details

# %%
above_500000
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 150    151      M   71.0  Central  58.66  Central   Science      58.0
# 177    178      F   73.0  Central  91.15   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  706250.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
print("Number of students getting salary above 5,00,000:",len(above_500000))
# Out:
# Number of students getting salary above 5,00,000: 3

# %% [markdown]
# Explanation:
# There are 3 students who received salaries above 5,00,000.
# Question-7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %% [markdown]
# Notes:
#     Hypothesis
#         1. Null Hypothesis (H0) : There is no significant difference between the means of etest_p and mba_p.
#         2. Alternative Hypothesis (H1) : There is a significant difference between the means of etest_p and mba_p

# %%
import scipy.stats as stats

stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=np.float64(98.64487057324709), pvalue=np.float64(4.672547689133636e-21))

# %% [markdown]
# Explanation:
# Desicion Rule:
#     if p-value < 0.05 --> reject H0
#     if p-value >=0.05 --> accept H0
#     since p-value < 0.05, reject the null hypothesis. (result=4.672*10 power of -21, so 0.000000000000000000000046)
#     There is a statiscally significant difference between etest_p and mba_p at the 5% significance level.
#
# Question-8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)¶

# %%
#Notes:
    #Hypothesis
      #  1. Null Hypothesis (H0) : There is no significant difference in salary between students belonging to Sci&Tech degree and Mkt&HR specialization.
       # 2. Alternative Hypothesis (H1) : There is a significant difference in salary between the means these groups.

# %%
from scipy.stats import ttest_ind
group1=dataset[dataset["degree_t"]=="Sci&Tech"]["salary"]
group2=dataset[dataset["specialisation"]=="Mkt&HR"]["salary"]

# %%
stats.f_oneway(group1,group2) #this is oneway classification answer
# Out:
# F_onewayResult(statistic=np.float64(7.247086057003171), pvalue=np.float64(0.007897969943471169))

# %%
t_statistic, p_values = ttest_ind(group1,group2,equal_var=False)#this is another way , but i am not sure which one we need to use here

# %%
print("T_statistic",t_statistic)
print("P_values",p_values)
# Out:
# T_statistic 2.584058295797713
# P_values 0.011110477852831742

# %% [markdown]
# Explanation:
#
# Decision Rule:
#     If P-value < 0.05 --> Reject H0
#
#     If P-value >=0.05 --> Accept H0
#
#     If the obtained p-value is less than 0.05, reject the null hypothesis.
#
#     otherwise, accept the null hypothesis.
#
# Question-9)Convert the normal distribution to standard normal distribution for salary column

# %%
salary = dataset[dataset["salary"]!=0]["salary"]#considering only placed students
mean=salary.mean()
std=salary.std()
print(mean,std)
# Out:
# 287076.0135135135 83857.17154814034

# %%
dataset["z_score"]=(dataset["salary"]-mean)/std #z-score fomula
print(dataset[["salary","z_score"]])
# Out:
#        salary   z_score
# 0    270000.0 -0.203632
# 1    200000.0 -1.038385
# 2    250000.0 -0.442133
# 3         0.0 -3.423393
# 4    425000.0  1.644749
# ..        ...       ...
# 210  400000.0  1.346623
# 211  275000.0 -0.144007
# 212  295000.0  0.094494
# 213  204000.0 -0.990685
# 214       0.0 -3.423393
#
# [215 rows x 2 columns]

# %% [markdown]
# Explanation:
#
# z-score conversion tranforms salary values into a standard normal distribution with:
#
#     - Mean=0
#
#     - Standard deviation =1
#
#     salary values were standaridized using the Z-score formula.
#
# Question-10)What is the probability Density Function of the salary range from 700000 to 900000?

# %%
# Density Polt
import seaborn as sns
x=dataset['salary']
ax = sns.distplot(dataset['salary'],kde=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19444\1683114438.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset['salary'],kde=True)

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset['salary'],700000,900000)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19444\132380739.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=197615.116, Standard Deviation=150305.844
# The area between range(700000,900000):0.0004137812663830048
# np.float64(0.0004137812663830048)

# %%
salary1 = dataset[dataset["salary"]!=0]["salary"] #anotherway without graph using CDF-Cumulative detribution function
mean1=salary1.mean()
std1=salary1.std()
print(mean1,std1)
# Out:
# 287076.0135135135 83857.17154814034

# %%
from scipy.stats import norm
probability=norm.cdf(900000,mean1,std1)-norm.cdf(700000,mean1,std1)
print("Probability:",probability)
# Out:
# Probability: 4.2367271091414693e-07

# %% [markdown]
# Explanation:
#
# -This calculates the probability of observing salaries between 7,00,000 and 9,00,000 assuming a normal distribution.
#
# -The probability of salary falling between 7,00,000 and 9,00,000 is approximately 0.00000538, indicating that such salaries are very rare.
#
#
#  Question-11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hy pothesis Testing)

# %% [markdown]
# Notes:
#     Hypothesis
#     1. Null Hypothesis(H0): There is no significant difference between etest_p and mba_p among Sci&Tech students.
#     2. Alternative Hypothesis(H1): There is a significant difference between etest_p and mba_p among Sci&Tech students.

# %%
from scipy.stats import ttest_ind
sci=dataset[dataset["degree_t"]=="Sci&Tech"]
etest=sci["etest_p"]
mba=sci["mba_p"]
t_stat,p_value=ttest_ind(etest,mba)
print("T-statistic:",t_stat)
print("P_value",p_value)
if p_value < 0.05:
    print("Reject Null Hypothesis")
else:
    print("Accept Null Hypothesis")
# Out:
# T-statistic: 4.532000225151251
# P_value 1.4289217003775655e-05
# Reject Null Hypothesis

# %% [markdown]
# Explanation:
#
# A t-test is used to determine whether the means differ significantly.
#
# Based on the obtained p-value, the hypothesis decision was made at the 5% siggnificance level.
#
# Question-12)Which parameter is highly correlated with salary?

# %%
dataset.corr(numeric_only=True) #this is one of the way we can find by the below tabular columns's result
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p  \
# sl_no     1.000000 -0.078155 -0.090500 -0.091039  0.063636  0.022327
# ssc_p    -0.078155  1.000000  0.513478  0.538686  0.261993  0.388478
# hsc_p    -0.090500  0.513478  1.000000  0.434606  0.240775  0.348452
# degree_p -0.091039  0.538686  0.434606  1.000000  0.227147  0.402376
# etest_p   0.063636  0.261993  0.240775  0.227147  1.000000  0.218055
# mba_p     0.022327  0.388478  0.348452  0.402376  0.218055  1.000000
# salary    0.001217  0.558475  0.459424  0.423762  0.186775  0.141417
# z_score   0.001217  0.558475  0.459424  0.423762  0.186775  0.141417
#
#             salary   z_score
# sl_no     0.001217  0.001217
# ssc_p     0.558475  0.558475
# hsc_p     0.459424  0.459424
# degree_p  0.423762  0.423762
# etest_p   0.186775  0.186775
# mba_p     0.141417  0.141417
# salary    1.000000  1.000000
# z_score   1.000000  1.000000

# %%
numeric_data=dataset.select_dtypes(include=["int64","float64"]) #another way to get only numeric columns
print(numeric_data)
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary   z_score
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0 -0.203632
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0 -1.038385
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0 -0.442133
# 3        4  56.00  52.00     52.00     66.0  59.43       0.0 -3.423393
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0  1.644749
# ..     ...    ...    ...       ...      ...    ...       ...       ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0  1.346623
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0 -0.144007
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0  0.094494
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0 -0.990685
# 214    215  62.00  58.00     53.00     89.0  60.22       0.0 -3.423393
#
# [215 rows x 8 columns]

# %%
correlation=numeric_data.corr()

# %%
correlation
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p  \
# sl_no     1.000000 -0.078155 -0.090500 -0.091039  0.063636  0.022327
# ssc_p    -0.078155  1.000000  0.513478  0.538686  0.261993  0.388478
# hsc_p    -0.090500  0.513478  1.000000  0.434606  0.240775  0.348452
# degree_p -0.091039  0.538686  0.434606  1.000000  0.227147  0.402376
# etest_p   0.063636  0.261993  0.240775  0.227147  1.000000  0.218055
# mba_p     0.022327  0.388478  0.348452  0.402376  0.218055  1.000000
# salary    0.001217  0.558475  0.459424  0.423762  0.186775  0.141417
# z_score   0.001217  0.558475  0.459424  0.423762  0.186775  0.141417
#
#             salary   z_score
# sl_no     0.001217  0.001217
# ssc_p     0.558475  0.558475
# hsc_p     0.459424  0.459424
# degree_p  0.423762  0.423762
# etest_p   0.186775  0.186775
# mba_p     0.141417  0.141417
# salary    1.000000  1.000000
# z_score   1.000000  1.000000

# %%
correlation["salary"].sort_values(ascending=False) #which we can get specific column with decending order
# Out:
# z_score     1.000000
# salary      1.000000
# ssc_p       0.558475
# hsc_p       0.459424
# degree_p    0.423762
# etest_p     0.186775
# mba_p       0.141417
# sl_no       0.001217
# Name: salary, dtype: float64

# %% [markdown]
# Explanation:
#
# The parameter having the highest positive correlation value (excluding salary itself and z_score) is identified.
#
# ssc_p has the highest correlation with salary among the numerical variables.
#
# Question-13) plot any useful graph and explain it.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.scatter(dataset["mba_p"],dataset["salary"])
plt.xlabel("MBA Pass mark")
plt.ylabel("Salary")
plt.title("Relationship between MBA Pass mark and Salary")
plt.show()

# %% [markdown]
# Explanation:
#
#     - Each point represent one student.
#
#     - X-axis shows MBA pass mark.
#
#     - Y-axis shows salary
#
#     - The graph indicates a weak positive relationship.
#
#     - Students with higher MBA pass mark do not always receive higher salaries.
